# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

from modules import KNN

# %%
female_data = pd.read_csv("data/ANSUR II FEMALE Public.csv")
female_data.head()
# Out:
#    SubjectId  abdominalextensiondepthsitting  acromialheight  \
# 0      10037                             231            1282
# 1      10038                             194            1379
# 2      10042                             183            1369
# 3      10043                             261            1356
# 4      10051                             309            1303
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    301                 204          1180
# 1                    320                 207          1292
# 2                    329                 233          1271
# 3                    306                 214          1250
# 4                    308                 214          1210
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      222               177                373
# 1                      225               178                372
# ...

# %%
male_data = pd.read_csv("data/ANSUR II MALE Public.csv", encoding="latin-1")
male_data.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0      10027                             266            1467
# 1      10032                             233            1395
# 2      10033                             287            1430
# 3      10092                             234            1347
# 4      10093                             250            1585
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    337                 222          1347
# 1                    326                 220          1293
# 2                    341                 230          1327
# 3                    310                 230          1239
# 4                    372                 247          1478
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      253               202                401
# 1                      245               193                394
# ...

# %%
data = pd.concat([female_data, male_data])
data
# Out:
#       SubjectId  abdominalextensiondepthsitting  acromialheight  \
# 0       10037.0                             231            1282
# 1       10038.0                             194            1379
# 2       10042.0                             183            1369
# 3       10043.0                             261            1356
# 4       10051.0                             309            1303
# ...         ...                             ...             ...
# 4077        NaN                             235            1353
# 4078        NaN                             247            1473
# 4079        NaN                             264            1394
# 4080        NaN                             203            1417
# 4081        NaN                             327            1523
#
#       acromionradialelength  anklecircumference  axillaheight  \
# 0                       301                 204          1180
# 1                       320                 207          1292
# ...

# %% [markdown]
# # PreProccess

# %%
data['weightkg'] = data['weightkg'] / 10    # Convert to kg
data['stature'] = data['stature'] / 10      # Convert to cm
data['Gender'] = data['Gender'].replace(['Female', 'Male'], [0, 1])     # Convert to binary

# %%
cmap = ['red', 'blue']
plt.scatter(data['stature'], data['weightkg'], c=data['Gender'], cmap=ListedColormap(cmap), alpha=0.1)
plt.xlabel('Stature (cm)')
plt.ylabel('weight (kg)')
plt.title('Distribution based on Stature and weight')
plt.grid(True)
plt.show()

# %%
f_data = data[data['Gender'] == 0]
m_data = data[data['Gender'] == 1]

# %%
plt.hist(f_data['stature'], color='red', label='Female')
plt.hist(m_data['stature'], alpha=0.7, color='blue', label='Male')

plt.xlabel('Stature (cm)')
plt.ylabel('Count')
plt.title('Stature Distribution by Gender')
plt.legend()
plt.grid(True)

plt.show()

# %%
X = data[['stature', 'weightkg']].values
Y = data['Gender'].values

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

print("Size of training set:", len(X_train))
print("Size of testing set:", len(X_test))
# Out:
# Size of training set: 4854
# Size of testing set: 1214

# %%
k = [3, 5, 7, 9]

# %% [markdown]
# ## Training and testing by my k-nearest-neighbors algorithm

# %%
accuracies = []
for i in k:
    knn = KNN(i)
    knn.fit(X_train, Y_train)
    accuracies.append(knn.evaluate(X_test, Y_test))

results_df = pd.DataFrame({
    'k': k,
    'Accuracy': accuracies
})

results_df
# Out:
#    k  Accuracy
# 0  3  0.825371
# 1  5  0.835255
# 2  7  0.832784
# 3  9  0.837727

# %%
Y_pred = knn.predict(X_test)

# %%
CM = np.zeros((2,2))

for i in range(int((len(data[["Gender"]])/100)*20)):
    if Y_test[i] == 0 and Y_pred[i] == 0:
        CM[0][0] += 1
    elif Y_test[i] == 0 and Y_pred[i] == 1:
        CM[0][1] += 1
    elif Y_test[i] == 1 and Y_pred[i] == 0:
        CM[1][0] += 1
    elif Y_test[i] == 1 and Y_pred[i] == 1:
        CM[1][1] += 1
    
CM
# Out:
# array([[302., 123.],
#        [ 74., 714.]])

# %%
plt.imshow(CM, interpolation='nearest', cmap=plt.cm.Wistia)
plt.colorbar()

classes = ['Female', 'Male']
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

thresh = CM.max() / 2.
for i in range(CM.shape[0]):
    for j in range(CM.shape[1]):
        plt.text(j, i, int(CM[i, j]),
                 horizontalalignment="center",
                 color="white" if CM[i, j] > thresh else "black")

plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion Matrix')

plt.show()

# %% [markdown]
# ## Training and testing by KNN algorithm with Scikit-learn

# %%
accuracies = []
for i in k:
    knn = KNeighborsClassifier(i)
    knn.fit(X_train, Y_train)
    accuracies.append(knn.score(X_test, Y_test))

results_df = pd.DataFrame({
    'k': k,
    'Accuracy': accuracies
})

results_df
# Out:
#    k  Accuracy
# 0  3  0.825371
# 1  5  0.836079
# 2  7  0.831960
# 3  9  0.837727

# %%
Y_pred = knn.predict(X_test)

# %%
cm = confusion_matrix(Y_test, Y_pred)
cm_display = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = ['Female', 'Male'])
cm_display.plot()
plt.show()
