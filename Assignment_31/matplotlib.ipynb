# %% [markdown]
# # Matplotlib Getting Started

# %%
import matplotlib.pyplot as plt
import numpy as np

print(matplotlib.__version__)
# Out:
# 3.5.2

# %% [markdown]
# # Matplotlib Pyplot

# %%
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
plt.plot(xpoints, ypoints, "o")
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints)
plt.show()

# %% [markdown]
# # Matplotlib Markers

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o')
plt.show()

# %% [markdown]
# # Format Strings fmt  (marker|line|color)

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:r')
plt.show()

# %% [markdown]
# # Marker Size

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %% [markdown]
# # Marker Color

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '*', ms = 20, mec = 'r')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '*', ms = 20, mfc = 'r')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '*', ms = 20, mec = '#4CAF50', mfc = '#4CAF50')
plt.show()

# %% [markdown]
# # Matplotlib Line (Linestyle)

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
plt.plot(ypoints, linestyle = 'dashed')

# %% [markdown]
# # Shorter Syntax

# %%
plt.plot(ypoints, ls = ':')

# %% [markdown]
# # Line Color

# %%
plt.plot(ypoints, color = 'r')
plt.show()

# %% [markdown]
# # Line Width

# %%
plt.plot(ypoints, linewidth = '15')
plt.show()

# %% [markdown]
# # Multiple Lines

# %%
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.show()

# %% [markdown]
# # Matplotlib Labels and Title

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %% [markdown]
# # Create a Title for a Plot

# %%
plt.plot(x, y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %% [markdown]
# # Set Font Properties for Title and Labels

# %%
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %% [markdown]
# # Position the Title

# %%
plt.title("Sports Watch Data", loc = 'left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)
plt.show()

# %% [markdown]
# # Matplotlib Adding Grid Lines

# %%
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()

# %% [markdown]
# ## Specify Which Grid Lines to Display

# %%
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'x')

plt.show()

# %%
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'y')

plt.show()

# %% [markdown]
# ## Set Line Properties for the Grid

# %%
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(color = 'red', linestyle = '--', linewidth = 0.5)

plt.show()

# %% [markdown]
# # Matplotlib Subplot

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)   # the figure has 1 row, 2 columns, and this plot is the first plot.
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)   # the figure has 1 row, 2 columns, and this plot is the second plot.
plt.plot(x,y)

plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %% [markdown]
# ## Title

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.show()

# %% [markdown]
# ## Super Title

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()

# %% [markdown]
# # Matplotlib Scatter

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %% [markdown]
# ## Compare Plots

# %%
#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %% [markdown]
# ## Colors

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')

plt.show()

# %% [markdown]
# ## Color Each Dot

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %% [markdown]
# ## ColorMap

# %%
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.show()

# %%
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %% [markdown]
# ## Size

# %%
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes)

plt.show()

# %% [markdown]
# ## Alpha

# %%
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes, alpha=0.5)

plt.show()

# %% [markdown]
# ## Combine Color Size and Alpha

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %% [markdown]
# # Matplotlib Bars

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %% [markdown]
# ## Horizontal Bars

# %%
plt.barh(x, y)
plt.show()

# %% [markdown]
# ## Bar Color

# %%
plt.bar(x, y, color = "red")
plt.show()

# %%
plt.bar(x, y, color = "hotpink")
plt.show()

# %%
plt.bar(x, y, color = "#4CAF50")
plt.show()

# %% [markdown]
# ## Bar Width

# %%
plt.bar(x, y, width = 0.1)
plt.show()

# %% [markdown]
# ## Bar Height

# %%
plt.barh(x, y, height = 0.1)
plt.show()

# %% [markdown]
# # Matplotlib Histograms

# %%
x = np.random.normal(170, 10, 250)

print(x)
# Out:
# [164.5838598  176.93250947 156.92084394 168.18300546 168.40813839
#  170.50581011 161.78315876 176.78875141 164.41052624 182.27301328
#  164.31897669 148.19279555 163.00240205 171.86288384 185.56216582
#  175.03879231 168.58124834 174.90740749 181.55027926 172.07093258
#  149.53313872 167.10834281 153.82326054 178.51207552 153.43269135
#  180.09880907 177.23132938 156.38909363 177.81257632 153.10176453
#  157.08613729 163.04123669 165.31120134 181.69572711 172.46319861
#  168.90684606 172.28213988 160.78989223 164.06007109 171.36593398
#  165.55946508 161.55543044 175.32144642 164.63540429 188.55937693
#  191.08208592 168.21110207 181.69945698 165.46156156 177.43606564
#  181.55769466 173.06663643 181.35081763 175.21176346 176.8483477
#  172.40616811 168.17876425 168.42209501 166.83769152 169.71937382
#  182.1235012  175.57224546 180.35419818 178.83767148 132.08052132
#  178.56222126 170.26294382 158.31637794 175.33879746 165.27524198
#  199.74123487 140.73022238 186.7166886  161.14559471 162.91616573
#  159.41431486 165.92045476 165.13926811 175.71980411 152.65314468
#  155.59304072 167.42851785 170.85217638 177.58348327 163.39652185
#  167.15840462 166.28129467 171.22462119 179.0994925  163.61872142
#  161.21886716 181.08282539 182.79690802 171.67878916 168.96883803
#  171.24181368 169.15803057 168.18712477 166.24791865 169.20697558
#  184.14446549 187.07441948 174.67043076 156.20969523 174.12749466
#  169.92509652 173.5419572  164.31331936 188.11159163 167.2051366
#  160.82867945 175.20144406 168.36819415 189.60029918 184.47963127
#  167.17737364 169.44972037 177.41295122 170.35692552 186.6857759
#  169.42058366 156.88890465 183.16491286 173.44581463 168.93719257
#  170.92301011 184.08514479 154.78033199 187.98867688 186.04822587
#  162.58150494 159.39841648 151.55346146 171.90081607 168.54212814
#  156.88125285 157.69796656 165.84623601 157.79824898 159.30752538
#  161.56720833 153.71852493 165.9082488  175.66381295 167.93428426
#  182.02882481 174.8792054  179.11786748 172.19922773 189.30409028
#  168.51766953 194.66259024 184.41859789 173.86137005 161.91725282
#  180.62872486 165.31528734 147.15590911 162.06688959 165.88185824
#  184.39056632 169.60116325 156.71678446 164.9288702  177.97070328
#  177.3037212  178.27108501 162.58759882 164.05670524 170.67611859
#  188.65831655 153.19258693 167.38987554 176.27903525 169.64462776
#  168.75708501 158.78002668 175.91388443 176.14686112 174.29626157
#  177.40036968 180.82087101 160.31843495 151.14608771 182.88431439
#  173.64715226 167.75501382 172.58518552 153.00345703 176.83207758
#  162.86097051 160.5452028  178.26352388 172.90278424 179.29265395
#  176.54694774 174.4744568  188.82089325 183.62860604 176.7263358
#  169.309348   162.40383373 168.36313694 184.49345009 177.86271189
#  162.22511387 145.24863619 173.01183228 165.43199795 158.83501846
#  172.51430754 185.72502626 165.73869846 170.94196144 179.40389808
#  177.91761883 184.27179854 161.46844103 182.86161486 156.36796284
#  169.91272564 163.76133497 177.72502133 192.26090536 164.13421964
#  163.11141104 162.378461   163.87479114 192.05883484 158.16086065
#  171.14252903 157.95387868 155.78798906 168.18924585 161.87910789
#  168.63583224 159.8092817  181.98888951 192.79781928 171.10014138
#  161.18902538 164.72041545 163.83156232 167.12044894 168.12261484
#  153.35395811 171.7071932  166.40213338 160.07353776 186.41526116]

# %%
plt.hist(x)
plt.show()

# %% [markdown]
# # Matplotlib Pie Charts

# %%
y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %% [markdown]
# ## Labels

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %% [markdown]
# ## Start Angle

# %%
plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %% [markdown]
# ## Explode

# %%
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %% [markdown]
# ## Shadow

# %%
plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %% [markdown]
# ## Colors

# %%
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %% [markdown]
# ## Legend

# %%
plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %% [markdown]
# ## Legend With Header

# %%
plt.pie(y, labels = mylabels)
plt.legend(title = "Four Fruits:")
plt.show()
