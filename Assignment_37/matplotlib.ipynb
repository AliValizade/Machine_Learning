# %% [markdown]
# # Matplotlib Getting Started

# %%
import matplotlib.pyplot as plt
import numpy as np

print(plt.matplotlib.__version__)
# Out:
# 3.6.2

# %% [markdown]
# # Matplotlib Pyplot

# %%
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
plt.plot(xpoints, ypoints, "o")
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints)
plt.show()

# %% [markdown]
# # Matplotlib Markers

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o')
plt.show()

# %% [markdown]
# # Format Strings fmt  (marker|line|color)

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:r')
plt.show()

# %% [markdown]
# # Marker Size

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %% [markdown]
# # Marker Color

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '*', ms = 20, mec = 'r')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '*', ms = 20, mfc = 'r')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '*', ms = 20, mec = '#4CAF50', mfc = '#4CAF50')
plt.show()

# %% [markdown]
# # Matplotlib Line (Linestyle)

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
plt.plot(ypoints, linestyle = 'dashed')

# %% [markdown]
# # Shorter Syntax

# %%
plt.plot(ypoints, ls = ':')

# %% [markdown]
# # Line Color

# %%
plt.plot(ypoints, color = 'r')
plt.show()

# %% [markdown]
# # Line Width

# %%
plt.plot(ypoints, linewidth = '15')
plt.show()

# %% [markdown]
# # Multiple Lines

# %%
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.show()

# %% [markdown]
# # Matplotlib Labels and Title

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %% [markdown]
# # Create a Title for a Plot

# %%
plt.plot(x, y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %% [markdown]
# # Set Font Properties for Title and Labels

# %%
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %% [markdown]
# # Position the Title

# %%
plt.title("Sports Watch Data", loc = 'left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)
plt.show()

# %% [markdown]
# # Matplotlib Adding Grid Lines

# %%
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()

# %% [markdown]
# ## Specify Which Grid Lines to Display

# %%
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'x')

plt.show()

# %%
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'y')

plt.show()

# %% [markdown]
# ## Set Line Properties for the Grid

# %%
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(color = 'red', linestyle = '--', linewidth = 0.5)

plt.show()

# %% [markdown]
# # Matplotlib Subplot

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)   # the figure has 1 row, 2 columns, and this plot is the first plot.
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)   # the figure has 1 row, 2 columns, and this plot is the second plot.
plt.plot(x,y)

plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %% [markdown]
# ## Title

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.show()

# %% [markdown]
# ## Super Title

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()

# %% [markdown]
# # Matplotlib Scatter

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %% [markdown]
# ## Compare Plots

# %%
#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %% [markdown]
# ## Colors

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')

plt.show()

# %% [markdown]
# ## Color Each Dot

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %% [markdown]
# ## ColorMap

# %%
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.show()

# %%
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %% [markdown]
# ## Size

# %%
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes)

plt.show()

# %% [markdown]
# ## Alpha

# %%
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes, alpha=0.5)

plt.show()

# %% [markdown]
# ## Combine Color Size and Alpha

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %% [markdown]
# # Matplotlib Bars

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %% [markdown]
# ## Horizontal Bars

# %%
plt.barh(x, y)
plt.show()

# %% [markdown]
# ## Bar Color

# %%
plt.bar(x, y, color = "red")
plt.show()

# %%
plt.bar(x, y, color = "hotpink")
plt.show()

# %%
plt.bar(x, y, color = "#4CAF50")
plt.show()

# %% [markdown]
# ## Bar Width

# %%
plt.bar(x, y, width = 0.1)
plt.show()

# %% [markdown]
# ## Bar Height

# %%
plt.barh(x, y, height = 0.1)
plt.show()

# %% [markdown]
# # Matplotlib Histograms

# %%
x = np.random.normal(170, 10, 250)

print(x)
# Out:
# [185.59081287 180.18240747 158.90395773 169.23573409 189.94315044
#  172.82846879 172.88177192 185.44040547 182.26842027 171.81907792
#  158.40789111 179.20353179 176.68374974 167.6646853  182.02335917
#  167.7727515  178.78489044 166.66654414 170.10424719 177.52655664
#  166.61481308 160.33179673 178.09444848 172.88663961 178.89271281
#  161.48194237 176.9604504  176.70378202 179.77285327 172.04379939
#  157.88656562 174.99887539 162.49206421 188.08077901 170.53907655
#  185.12405841 183.65769655 157.54820747 170.78090458 152.73361911
#  174.07569846 175.6236868  175.01923564 164.29958385 179.21309478
#  188.26240241 189.18059222 169.58993862 174.7537456  171.44543215
#  165.39390881 177.37682902 178.1997992  168.35075814 155.0553732
#  173.31756283 166.72736272 164.95848507 169.22665738 157.92515576
#  189.13196049 168.2462952  165.86715877 180.54747216 180.12852124
#  170.46216146 176.09443769 168.90128891 156.78437582 167.04845542
#  167.15900322 171.57350821 182.88121073 181.4534116  162.38577334
#  141.26357651 147.68230109 173.84716812 167.20268158 166.01749042
#  178.57710572 160.08588149 164.36835299 173.90017937 163.87609408
#  158.71365911 184.83471056 170.36777864 185.61707972 178.73608269
#  168.01366056 163.95091729 163.94863442 172.29437462 177.33142046
#  156.53174534 163.11236049 153.33176282 178.06619963 179.90067801
#  155.38831905 174.1381341  180.03979849 171.06673351 168.49546594
#  176.70293517 187.60769383 158.09740224 167.49940997 181.01875318
#  150.97893762 174.07402713 183.51069544 163.49265951 158.72428237
#  162.62931195 169.08971081 170.86201628 181.17574772 178.51648694
#  179.42168794 170.31176017 182.37550038 147.29173447 154.84769014
#  187.71533947 163.3847735  177.44857267 172.25446969 167.04046589
#  174.10986546 155.08360152 163.08034438 185.44634499 167.16441021
#  173.62654758 175.25152022 166.11525284 161.13489917 184.83455521
#  179.62247318 164.20681892 182.50429843 170.83022042 173.28870537
#  165.95413514 153.73081448 189.19117405 182.09246268 156.78429778
#  177.9866975  175.83927452 171.02268232 191.22862342 186.27181333
#  179.24496994 169.04141863 179.22769836 185.35408657 172.55307238
#  170.11872502 174.53997709 170.27988436 163.89611227 185.19165562
#  155.22355771 173.6006998  172.10294736 187.23870672 164.28689546
#  153.40243259 164.56436187 160.87828142 181.93726601 197.56648204
#  186.85808108 177.08206745 182.84973232 159.81655933 175.44764944
#  168.96664902 177.73505003 178.75963667 185.40170889 158.63897697
#  167.6707454  169.8888189  184.22812357 183.68572831 190.30299403
#  151.48617    169.22961071 169.22412627 178.14113472 158.17630308
#  176.45942366 185.45862338 180.23610922 167.69860324 161.67909231
#  169.10048808 170.83355965 177.32137001 177.5458096  171.23064965
#  175.67241267 162.93369734 169.24317477 179.36220035 188.31024488
#  164.40665466 161.39877308 189.3747252  171.56705073 166.24289248
#  168.84162753 176.35035787 156.25426577 179.88032192 186.36181631
#  151.77774295 166.20194532 170.7650614  175.84913189 171.64996869
#  171.82777522 160.27800618 169.15220157 160.29737239 155.67456431
#  182.93928821 188.06227906 164.71851575 174.43799904 155.86949172
#  164.93225435 159.61814447 154.09600622 172.0388019  191.60139123
#  187.50711732 159.21756795 177.77329073 173.43600633 153.59666368
#  189.57064938 163.64044558 186.69071489 141.57915049 158.89678051]

# %%
plt.hist(x)
plt.show()

# %% [markdown]
# # Matplotlib Pie Charts

# %%
y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %% [markdown]
# ## Labels

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %% [markdown]
# ## Start Angle

# %%
plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %% [markdown]
# ## Explode

# %%
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %% [markdown]
# ## Shadow

# %%
plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %% [markdown]
# ## Colors

# %%
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %% [markdown]
# ## Legend

# %%
plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %% [markdown]
# ## Legend With Header

# %%
plt.pie(y, labels = mylabels)
plt.legend(title = "Four Fruits:")
plt.show()
