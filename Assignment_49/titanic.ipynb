# %% [markdown]
# # TITANIC dataset
# * PreProccess

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.metrics import confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay

# %%
data_train = pd.read_csv('train.csv')
data_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data_train.replace(['female','male'], [0, 1], inplace=True)
data_train.fillna(0, inplace=True)
data_train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
# 5                                   Moran, Mr. James    1   0.0      0      0
# 6                            McCarthy, Mr. Timothy J    1  54.0      0      0
# 7                     Palsson, Master. Gosta Leonard    1   2.0      3      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    0  27.0      0      2
# 9                Nasser, Mrs. Nicholas (Adele Achem)    0  14.0      1      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500     0        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250     0        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500     0        S
# 5            330877   8.4583     0        Q
# 6             17463  51.8625   E46        S
# 7            349909  21.0750     0        S
# 8            347742  11.1333     0        S
# 9            237736  30.0708     0        C

# %%
X_train = np.array(data_train[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare']])
y_train = np.array(data_train[['Survived']])

# %% [markdown]
# # **Model**

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(6, activation='sigmoid'), # input
    tf.keras.layers.Dense(20, activation='relu'), # hidden 1
    tf.keras.layers.Dense(8, activation='sigmoid'), # hidden 2
    tf.keras.layers.Dense(2, activation='softmax') # output
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
output = model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.4777 - loss: 0.6911
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6248 - loss: 0.6585
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6409 - loss: 0.6395
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6316 - loss: 0.6304
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5861 - loss: 0.6424
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6251 - loss: 0.6191
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6659 - loss: 0.6135
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6787 - loss: 0.6150
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6924 - loss: 0.6039
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7031 - loss: 0.5936
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7007 - loss: 0.5931
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6960 - loss: 0.5848
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6866 - loss: 0.5887
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6925 - loss: 0.5835
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6841 - loss: 0.5960
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6568 - loss: 0.6063
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6713 - loss: 0.5878
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6837 - loss: 0.5748
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7049 - loss: 0.5692
# Epoch 20/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7105 - loss: 0.5680
# Epoch 21/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7144 - loss: 0.5546
# Epoch 22/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6642 - loss: 0.6026
# Epoch 23/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6929 - loss: 0.5697
# Epoch 24/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6833 - loss: 0.5750
# Epoch 25/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6765 - loss: 0.5823
# Epoch 26/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7013 - loss: 0.5568
# Epoch 27/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7034 - loss: 0.5547
# Epoch 28/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7055 - loss: 0.5627
# Epoch 29/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7051 - loss: 0.5571
# Epoch 30/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6970 - loss: 0.5704
# Epoch 31/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7084 - loss: 0.5547
# Epoch 32/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6977 - loss: 0.5501
# Epoch 33/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7025 - loss: 0.5443
# Epoch 34/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7282 - loss: 0.5445
# Epoch 35/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7022 - loss: 0.5497
# Epoch 36/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7132 - loss: 0.5362
# Epoch 37/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7446 - loss: 0.5187
# Epoch 38/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7483 - loss: 0.5230
# Epoch 39/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7575 - loss: 0.5085
# Epoch 40/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7576 - loss: 0.4872
# Epoch 41/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7647 - loss: 0.5022
# Epoch 42/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7511 - loss: 0.5011
# Epoch 43/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7284 - loss: 0.5304
# Epoch 44/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7601 - loss: 0.4935
# Epoch 45/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8032 - loss: 0.4661
# Epoch 46/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7801 - loss: 0.4796
# Epoch 47/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7974 - loss: 0.4638
# Epoch 48/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7664 - loss: 0.4848
# Epoch 49/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8005 - loss: 0.4583
# Epoch 50/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7925 - loss: 0.4610
# Epoch 51/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7906 - loss: 0.4653
# Epoch 52/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8038 - loss: 0.4617
# Epoch 53/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.
head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
X_test = np.array(data_test[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare']])
Y_test = np.array(data_target[['Survived']])

# %%
result = model.evaluate(X_test, Y_test)
print(f'Loss: {result[0]}')
print(f'Accuracy: {result[1]}')
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9319 - loss: 0.2785
# Loss: 0.2682684063911438
# Accuracy: 0.940191388130188

# %% [markdown]
# # Calculate **precision** and **recall**

# %%
y_pred = np.argmax(model.predict(X_test), axis=1)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
cm = confusion_matrix(Y_test, y_pred)
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[259   7]
#  [ 18 134]]

# %%
displiay_cm = ConfusionMatrixDisplay(confusion_matrix=cm)
displiay_cm.plot(cmap=plt.cm.Blues)
plt.show()

# %%
precision = precision_score(Y_test, y_pred)
recall = recall_score(Y_test, y_pred)

print(f'Precision: {precision}')
print(f'Recall: {recall}')
# Out:
# Precision: 0.950354609929078
# Recall: 0.881578947368421

# %% [markdown]
# # ***Jack*** and ***Rose*** survival prediction

# %%
jack = np.array([[3, 1, 20, 0, 0, 5]])
rose = np.array([[1, 0, 19, 1, 0, 100]])

# %%
jack_pred = np.argmax(model.predict(jack), axis=1)
rose_pred = np.argmax(model.predict(rose), axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %%
print(f"Jack's survival prediction: {'Survived' if jack_pred == 1 else 'Did not survive'}")
print(f"Rose's survival prediction: {'Survived' if rose_pred == 1 else 'Did not survive'}")
# Out:
# Jack's survival prediction: Did not survive
# Rose's survival prediction: Survived

# %% [markdown]
# # ***KNN***

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# KNN model
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train.ravel())

# Predict & calculate accuracy
knn_pred = knn.predict(X_test)
knn_accuracy = accuracy_score(Y_test, knn_pred)
print(f"KNN Accuracy: {knn_accuracy}")
# Out:
# KNN Accuracy: 0.6698564593301436

# %% [markdown]
# ## ***Perceptron***

# %%
from sklearn.linear_model import Perceptron

# Perceptron model
perceptron = Perceptron()
perceptron.fit(X_train, y_train.ravel())

# Predict & calculate accuracy
perceptron_pred = perceptron.predict(X_test)
perceptron_accuracy = accuracy_score(Y_test, perceptron_pred)
print(f"Perceptron Accuracy: {perceptron_accuracy}")
# Out:
# Perceptron Accuracy: 0.7177033492822966

# %% [markdown]
# ## Comparing the accuracy of **KNN**, **Perceptron** and **MLP** algorithms

# %%
results = pd.DataFrame({
    'Algorithm': ['KNN', 'Perceptron', 'MLP (Multi-Layer Perceptron)'],
    'Accuracy': [knn_accuracy, perceptron_accuracy, result[1]]
})

results
# Out:
#                       Algorithm  Accuracy
# 0                           KNN  0.669856
# 1                    Perceptron  0.717703
# 2  MLP (Multi-Layer Perceptron)  0.940191
